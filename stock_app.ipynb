# %%
import pandas as pd

stock_path="Resources/Current_Portfolio_Positions.csv"

df=pd.read_csv(stock_path).dropna()

#column to calcute distribution of funds
col='Total Gain/Loss Percent'
#funds to invest
funds_to_invest=300

new_df=df.loc[:,df.columns.intersection(["Symbol",col])]

new_df[col]=pd.to_numeric(new_df.loc[:,col].str.rstrip('%'),errors='coerce')


new_df=new_df.dropna()



negative_loss_df=new_df.loc[new_df[col]<0]



total_loss_percent=negative_loss_df.loc[:,col].sum()

negative_loss_df['%_of_sum_of_percent_loss']=negative_loss_df.loc[:,col]/total_loss_percent

negative_loss_df['funds_to_distribute']=negative_loss_df.loc[:,'%_of_sum_of_percent_loss']*funds_to_invest

negative_loss_df
# Out:
# C:\Users\Silho\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#   Symbol  Total Gain/Loss Percent  %_of_sum_of_percent_loss  \
# 2    WBA                    -7.80                  0.350719
# 3     RF                    -6.23                  0.280126
# 4    MFC                    -5.96                  0.267986
# 5   QYLD                    -1.10                  0.049460
# 6    UNM                    -0.96                  0.043165
# 7    MSM                    -0.19                  0.008543
#
#    funds_to_distribute
# 2           105.215827
# 3            84.037770
# 4            80.395683
# 5            14.838129
# 6            12.949640
# 7             2.562950
