# %%
import pandas as pd

stock_path="Resources/Current_Portfolio_Positions.csv"

df=pd.read_csv(stock_path).dropna()

#column to calcute distribution of funds
col="Today's Gain/Loss Percent"
col2="Today's Gain/Loss Dollar"

new_df=df.loc[:,df.columns.intersection(["Symbol",col,col2])]


new_df[col]=pd.to_numeric(new_df.loc[:,col].str.rstrip('%'),errors='coerce')

new_df[col2]=pd.to_numeric(new_df[col2].str.replace('\((.*)\)', '-\\1').str.replace('$', ''),errors='coerce')



negative_loss_df=new_df.loc[new_df[col]<0]

funds_to_invest=new_df[col2].sum()*-1



total_loss_percent=negative_loss_df.loc[:,col].sum()


negative_loss_df['%_of_sum_of_percent_loss']=negative_loss_df.loc[:,col]/total_loss_percent


negative_loss_df['funds_to_distribute']=round(negative_loss_df.loc[:,'%_of_sum_of_percent_loss']*funds_to_invest,2)

negative_loss_df
# Out:
# <ipython-input-83-a5a56626b202>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df[col2]=pd.to_numeric(new_df[col2].str.replace('\((.*)\)', '-\\1').str.replace('$', ''),errors='coerce')
# <ipython-input-83-a5a56626b202>:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df[col2]=pd.to_numeric(new_df[col2].str.replace('\((.*)\)', '-\\1').str.replace('$', ''),errors='coerce')
# C:\Users\Silho\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#    Symbol  Today's Gain/Loss Dollar  Today's Gain/Loss Percent  \
# 2    ARCC                     -1.39                      -0.68
# 3    AVGO                    -12.42                      -0.83
# 4    FLIC                     -1.36                      -1.77
# 6     GPC                     -7.10                      -2.25
# 9     MFC                    -10.42                      -1.35
# 10    MSM                     -1.99                      -1.08
# 11      O                     -1.30                      -0.53
# 12    PEP                     -0.54                      -0.11
# 13    PRU                     -7.53                      -1.75
# 15     RF                     -5.05                      -0.91
# 16   SCHD                     -0.90                      -0.73
# 18   STOR                     -3.73                      -1.30
# 19    UGI                     -0.34                      -0.50
# 20    UNM                     -5.17                      -1.40
# 21    WBA                     -2.58                      -0.35
#
#     %_of_sum_of_percent_loss  funds_to_distribute
# 2                   0.043758                 2.11
# 3                   0.053411                 2.58
# 4                   0.113900                 5.49
# 6                   0.144788                 6.98
# 9                   0.086873                 4.19
# 10                  0.069498                 3.35
# 11                  0.034106                 1.64
# 12                  0.007079                 0.34
# 13                  0.112613                 5.43
# 15                  0.058559                 2.82
# 16                  0.046976                 2.27
# 18                  0.083655                 4.03
# 19                  0.032175                 1.55
# 20                  0.090090                 4.35
# 21                  0.022523                 1.09

# %%
negative_loss_df['funds_to_distribute'].sum()
# Out:
# 48.220000000000006
